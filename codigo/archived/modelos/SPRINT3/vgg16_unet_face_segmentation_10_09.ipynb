# %%
# Monta o Google Drive para acessar arquivos
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from PIL import Image, ImageEnhance

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D,
    concatenate, BatchNormalization, Activation, LeakyReLU
)
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.applications import VGG16
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.layers import Dense, Conv2DTranspose, UpSampling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Conv2D, UpSampling2D, Dropout

from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.metrics import CategoricalAccuracy, MeanIoU
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l1_l2

from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split

import h5py

# %%
# Caminho para o arquivo HDF5 no Google Drive
file_path = '/content/drive/MyDrive/PROJETO/g5_dataset_augmented_processed_28_ago.h5'

# Carregando os arrays do arquivo HDF5
with h5py.File(file_path, 'r') as h5f:
    X__train = h5f['x_train'][:]
    X_test = h5f['x_test'][:]
    y_train = h5f['y_train'][:]
    y_test = h5f['y_test'][:]

# %%
X__train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((9570, 128, 128, 3),
#  (798, 128, 128, 3),
#  (9570, 128, 128, 3),
#  (798, 128, 128, 3))

# %%
random_index = np.random.randint(0, y_test.shape[0])

imageX = X__train[random_index]
image = y_train[random_index]

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(imageX)


plt.subplot(1, 2, 2)
plt.imshow(image)

# %%
def transform_red_to_white(mask):
    # Criando uma máscara binária onde vermelho (255, 0, 0) se torna branco (255, 255, 255)
    white_mask = np.copy(mask)
    red_pixels = (mask[:, :, 0] == 255) & (mask[:, :, 1] == 0) & (mask[:, :, 2] == 0)
    white_mask[red_pixels] = [255, 255, 255]

    # Binarizando a máscara (tudo que é branco vira 1, o resto vira 0)
    binary_mask = np.where((white_mask[:, :, 0] == 255) &
                           (white_mask[:, :, 1] == 255) &
                           (white_mask[:, :, 2] == 255), 1, 0)
    return binary_mask

# %%
index = 0  # Índice da imagem de exemplo para inspeção
original_mask = y_train[index]
processed_mask = transform_red_to_white(original_mask)

# Plotando a máscara original e a processada para comparação
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title("Máscara Original")
plt.imshow(original_mask)

plt.subplot(1, 2, 2)
plt.title("Máscara Processada")
plt.imshow(processed_mask, cmap='gray')

# %%
y_train_processed = np.array([transform_red_to_white(mask) for mask in y_train])
y_test_processed = np.array([transform_red_to_white(mask) for mask in y_test])

# %%
y_train_processed.shape
# Out:
# (9570, 128, 128)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, Input, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

def build_lightweight_unet(input_shape):
    # Entrada
    inputs = Input(input_shape)

    # Encoder
    # Bloco 1
    c1 = Conv2D(16, (3, 3), activation='relu', padding='same')(inputs)
    c1 = BatchNormalization()(c1)
    c1 = Conv2D(16, (3, 3), activation='relu', padding='same')(c1)
    c1 = BatchNormalization()(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(0.1)(p1)

    # Bloco 2
    c2 = Conv2D(32, (3, 3), activation='relu', padding='same')(p1)
    c2 = BatchNormalization()(c2)
    c2 = Conv2D(32, (3, 3), activation='relu', padding='same')(c2)
    c2 = BatchNormalization()(c2)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(0.1)(p2)

    # Bloco 3
    c3 = Conv2D(64, (3, 3), activation='relu', padding='same')(p2)
    c3 = BatchNormalization()(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', padding='same')(c3)
    c3 = BatchNormalization()(c3)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(0.2)(p3)

    # Bloco 4
    c4 = Conv2D(128, (3, 3), activation='relu', padding='same')(p3)
    c4 = BatchNormalization()(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', padding='same')(c4)
    c4 = BatchNormalization()(c4)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(0.2)(p4)

    # Bridge
    b = Conv2D(256, (3, 3), activation='relu', padding='same')(p4)
    b = BatchNormalization()(b)
    b = Dropout(0.3)(b)

    # Decoder
    # Bloco 6
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(b)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same')(u6)
    c6 = BatchNormalization()(c6)
    c6 = Dropout(0.2)(c6)

    # Bloco 7
    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same')(u7)
    c7 = BatchNormalization()(c7)
    c7 = Dropout(0.2)(c7)

    # Bloco 8
    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', padding='same')(u8)
    c8 = BatchNormalization()(c8)
    c8 = Dropout(0.1)(c8)

    # Bloco 9
    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1])
    c9 = Conv2D(16, (3, 3), activation='relu', padding='same')(u9)
    c9 = BatchNormalization()(c9)
    c9 = Dropout(0.1)(c9)

    # Camada de saída
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])
    return model

# Especificando o tamanho da entrada
input_shape = (128, 128, 3)
unet_model = build_lightweight_unet(input_shape)

from tensorflow.keras import backend as K

def dice_loss(y_true, y_pred):
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    intersection = K.sum(y_true * y_pred)
    return 1 - (2. * intersection + K.epsilon()) / (K.sum(y_true) + K.sum(y_pred) + K.epsilon())

from tensorflow.keras.callbacks import LearningRateScheduler

# Função de learning rate cíclico
def cyclical_learning_rate(epoch, lr):
    base_lr = 1e-5  # valor mínimo da taxa de aprendizado
    max_lr = 1e-3  # valor máximo da taxa de aprendizado
    step_size = 10  # quantidade de épocas por ciclo
    cycle = np.floor(1 + epoch / (2 * step_size))
    x = np.abs(epoch / step_size - 2 * cycle + 1)
    new_lr = base_lr + (max_lr - base_lr) * np.maximum(0, (1 - x))
    return new_lr

# Callback para ajustar o learning rate a cada época
lr_scheduler = LearningRateScheduler(cyclical_learning_rate)

# Compilando o modelo
unet_model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss='binary_crossentropy',
    metrics=[
        tf.keras.metrics.BinaryAccuracy(),
        tf.keras.metrics.Precision(),
        tf.keras.metrics.Recall(),
        tf.keras.metrics.AUC()
    ]
)

unet_model.summary()
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_7             │ (None, 128, 128, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_113 (Conv2D)       │ (None, 128, 128, 16)   │            448 │ input_layer_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_52    │ (None, 128, 128, 16)   │             64 │ conv2d_113[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_114 (Conv2D)       │ (None, 128, 128, 16)   │          2,320 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_53    │ (None, 128, 128, 16)   │             64 │ conv2d_114[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_28          │ (None, 64, 64, 16)     │              0 │ batch_normalization_5… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_36 (Dropout)      │ (None, 64, 64, 16)     │              0 │ max_pooling2d_28[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_115 (Conv2D)       │ (None, 64, 64, 32)     │          4,640 │ dropout_36[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_54    │ (None, 64, 64, 32)     │            128 │ conv2d_115[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_116 (Conv2D)       │ (None, 64, 64, 32)     │          9,248 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_55    │ (None, 64, 64, 32)     │            128 │ conv2d_116[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_29          │ (None, 32, 32, 32)     │              0 │ batch_normalization_5… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_37 (Dropout)      │ (None, 32, 32, 32)     │              0 │ max_pooling2d_29[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_117 (Conv2D)       │ (None, 32, 32, 64)     │         18,496 │ dropout_37[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_56    │ (None, 32, 32, 64)     │            256 │ conv2d_117[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_118 (Conv2D)       │ (None, 32, 32, 64)     │         36,928 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_57    │ (None, 32, 32, 64)     │            256 │ conv2d_118[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_30          │ (None, 16, 16, 64)     │              0 │ batch_normalization_5… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_38 (Dropout)      │ (None, 16, 16, 64)     │              0 │ max_pooling2d_30[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_119 (Conv2D)       │ (None, 16, 16, 128)    │         73,856 │ dropout_38[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_58    │ (None, 16, 16, 128)    │            512 │ conv2d_119[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_120 (Conv2D)       │ (None, 16, 16, 128)    │        147,584 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_59    │ (None, 16, 16, 128)    │            512 │ conv2d_120[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_31          │ (None, 8, 8, 128)      │              0 │ batch_normalization_5… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_39 (Dropout)      │ (None, 8, 8, 128)      │              0 │ max_pooling2d_31[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_121 (Conv2D)       │ (None, 8, 8, 256)      │        295,168 │ dropout_39[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_60    │ (None, 8, 8, 256)      │          1,024 │ conv2d_121[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_40 (Dropout)      │ (None, 8, 8, 256)      │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_28       │ (None, 16, 16, 128)    │        131,200 │ dropout_40[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_28            │ (None, 16, 16, 256)    │              0 │ conv2d_transpose_28[0… │
# │ (Concatenate)             │                        │                │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_122 (Conv2D)       │ (None, 16, 16, 128)    │        295,040 │ concatenate_28[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_61    │ (None, 16, 16, 128)    │            512 │ conv2d_122[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_41 (Dropout)      │ (None, 16, 16, 128)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_29       │ (None, 32, 32, 64)     │         32,832 │ dropout_41[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_29            │ (None, 32, 32, 128)    │              0 │ conv2d_transpose_29[0… │
# │ (Concatenate)             │                        │                │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_123 (Conv2D)       │ (None, 32, 32, 64)     │         73,792 │ concatenate_29[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_62    │ (None, 32, 32, 64)     │            256 │ conv2d_123[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_42 (Dropout)      │ (None, 32, 32, 64)     │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_30       │ (None, 64, 64, 32)     │          8,224 │ dropout_42[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_30            │ (None, 64, 64, 64)     │              0 │ conv2d_transpose_30[0… │
# │ (Concatenate)             │                        │                │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_124 (Conv2D)       │ (None, 64, 64, 32)     │         18,464 │ concatenate_30[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_63    │ (None, 64, 64, 32)     │            128 │ conv2d_124[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_43 (Dropout)      │ (None, 64, 64, 32)     │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_31       │ (None, 128, 128, 16)   │          2,064 │ dropout_43[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_31            │ (None, 128, 128, 32)   │              0 │ conv2d_transpose_31[0… │
# │ (Concatenate)             │                        │                │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_125 (Conv2D)       │ (None, 128, 128, 16)   │          4,624 │ concatenate_31[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_64    │ (None, 128, 128, 16)   │             64 │ conv2d_125[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_44 (Dropout)      │ (None, 128, 128, 16)   │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_126 (Conv2D)       │ (None, 128, 128, 1)    │             17 │ dropout_44[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,158,849 (4.42 MB)
#  Trainable params: 1,156,897 (4.41 MB)
#  Non-trainable params: 1,952 (7.62 KB)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train_train, y_val_val = train_test_split(X__train, y_train_processed, test_size=0.2, random_state=42)

# Verificando os tamanhos dos conjuntos
print(f"Tamanho do conjunto de treinamento: {X_train.shape}")
print(f"Tamanho do conjunto de validação: {X_val.shape}")
print(f"Tamanho do conjunto de treino: {y_train_train.shape}")
print(f"Tamanho do conjunto de validação: {y_val_val.shape}")
# Out:
# Tamanho do conjunto de treinamento: (7656, 128, 128, 3)
# Tamanho do conjunto de validação: (1914, 128, 128, 3)
# Tamanho do conjunto de treino: (7656, 128, 128)
# Tamanho do conjunto de validação: (1914, 128, 128)

# %%
y_train_train = tf.expand_dims(y_train_train, axis=-1)
y_val_val = tf.expand_dims(y_val_val, axis=-1)

# %%
print(f"Tamanho do conjunto de treino: {y_train_train.shape}")
print(f"Tamanho do conjunto de validação: {y_val_val.shape}")
# Out:
# Tamanho do conjunto de treino: (7656, 128, 128, 1)
# Tamanho do conjunto de validação: (1914, 128, 128, 1)

# %%
ndex = 0  # Índice da imagem de exemplo para inspeção
mask = y_train_train[index]

# Plotando a máscara original e a processada para comparação
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title("Máscara ")
plt.imshow(mask)

# %%
# Configurando early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Treinando o modelo
history = unet_model.fit(X_train, y_train_train,
                         epochs=40,
                         batch_size=16,
                         validation_data=(X_val, y_val_val),
                         callbacks=[early_stopping, lr_scheduler])
# Out:
# Epoch 1/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 41s 42ms/step - auc_6: 0.5885 - binary_accuracy: 0.5694 - loss: 0.7797 - precision_6: 0.4482 - recall_6: 0.5217 - val_auc_6: 0.8500 - val_binary_accuracy: 0.7778 - val_loss: 0.5462 - val_precision_6: 0.6736 - val_recall_6: 0.8052 - learning_rate: 1.0000e-05
# Epoch 2/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.8797 - binary_accuracy: 0.8156 - loss: 0.4361 - precision_6: 0.7628 - recall_6: 0.7506 - val_auc_6: 0.9021 - val_binary_accuracy: 0.8323 - val_loss: 0.3801 - val_precision_6: 0.8000 - val_recall_6: 0.7448 - learning_rate: 1.0900e-04
# Epoch 3/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9019 - binary_accuracy: 0.8314 - loss: 0.3865 - precision_6: 0.7929 - recall_6: 0.7569 - val_auc_6: 0.9092 - val_binary_accuracy: 0.8364 - val_loss: 0.3800 - val_precision_6: 0.7757 - val_recall_6: 0.8009 - learning_rate: 2.0800e-04
# Epoch 4/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9098 - binary_accuracy: 0.8401 - loss: 0.3659 - precision_6: 0.8098 - recall_6: 0.7587 - val_auc_6: 0.9153 - val_binary_accuracy: 0.8312 - val_loss: 0.3875 - val_precision_6: 0.7438 - val_recall_6: 0.8478 - learning_rate: 3.0700e-04
# Epoch 5/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9163 - binary_accuracy: 0.8460 - loss: 0.3516 - precision_6: 0.8176 - recall_6: 0.7661 - val_auc_6: 0.9048 - val_binary_accuracy: 0.8350 - val_loss: 0.3876 - val_precision_6: 0.8310 - val_recall_6: 0.7100 - learning_rate: 4.0600e-04
# Epoch 6/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9189 - binary_accuracy: 0.8489 - loss: 0.3457 - precision_6: 0.8256 - recall_6: 0.7691 - val_auc_6: 0.9218 - val_binary_accuracy: 0.8486 - val_loss: 0.3442 - val_precision_6: 0.7934 - val_recall_6: 0.8131 - learning_rate: 5.0500e-04
# Epoch 7/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9233 - binary_accuracy: 0.8537 - loss: 0.3360 - precision_6: 0.8344 - recall_6: 0.7729 - val_auc_6: 0.9211 - val_binary_accuracy: 0.8391 - val_loss: 0.3597 - val_precision_6: 0.7601 - val_recall_6: 0.8426 - learning_rate: 6.0400e-04
# Epoch 8/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9258 - binary_accuracy: 0.8568 - loss: 0.3298 - precision_6: 0.8353 - recall_6: 0.7766 - val_auc_6: 0.9250 - val_binary_accuracy: 0.8560 - val_loss: 0.3337 - val_precision_6: 0.8527 - val_recall_6: 0.7507 - learning_rate: 7.0300e-04
# Epoch 9/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9288 - binary_accuracy: 0.8596 - loss: 0.3238 - precision_6: 0.8413 - recall_6: 0.7803 - val_auc_6: 0.9245 - val_binary_accuracy: 0.8517 - val_loss: 0.3420 - val_precision_6: 0.8711 - val_recall_6: 0.7156 - learning_rate: 8.0200e-04
# Epoch 10/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9296 - binary_accuracy: 0.8601 - loss: 0.3223 - precision_6: 0.8416 - recall_6: 0.7837 - val_auc_6: 0.9260 - val_binary_accuracy: 0.8564 - val_loss: 0.3309 - val_precision_6: 0.8189 - val_recall_6: 0.7984 - learning_rate: 9.0100e-04
# Epoch 11/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9317 - binary_accuracy: 0.8630 - loss: 0.3172 - precision_6: 0.8437 - recall_6: 0.7877 - val_auc_6: 0.9229 - val_binary_accuracy: 0.8426 - val_loss: 0.3603 - val_precision_6: 0.7655 - val_recall_6: 0.8441 - learning_rate: 0.0010
# Epoch 12/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9341 - binary_accuracy: 0.8647 - loss: 0.3117 - precision_6: 0.8462 - recall_6: 0.7887 - val_auc_6: 0.9313 - val_binary_accuracy: 0.8627 - val_loss: 0.3180 - val_precision_6: 0.8539 - val_recall_6: 0.7703 - learning_rate: 9.0100e-04
# Epoch 13/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9379 - binary_accuracy: 0.8691 - loss: 0.3029 - precision_6: 0.8510 - recall_6: 0.7955 - val_auc_6: 0.9305 - val_binary_accuracy: 0.8613 - val_loss: 0.3215 - val_precision_6: 0.8452 - val_recall_6: 0.7772 - learning_rate: 8.0200e-04
# Epoch 14/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9411 - binary_accuracy: 0.8724 - loss: 0.2955 - precision_6: 0.8561 - recall_6: 0.8025 - val_auc_6: 0.9324 - val_binary_accuracy: 0.8648 - val_loss: 0.3188 - val_precision_6: 0.8403 - val_recall_6: 0.7952 - learning_rate: 7.0300e-04
# Epoch 15/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9432 - binary_accuracy: 0.8751 - loss: 0.2892 - precision_6: 0.8572 - recall_6: 0.8041 - val_auc_6: 0.9322 - val_binary_accuracy: 0.8630 - val_loss: 0.3172 - val_precision_6: 0.8399 - val_recall_6: 0.7899 - learning_rate: 6.0400e-04
# Epoch 16/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9464 - binary_accuracy: 0.8780 - loss: 0.2826 - precision_6: 0.8620 - recall_6: 0.8130 - val_auc_6: 0.9351 - val_binary_accuracy: 0.8660 - val_loss: 0.3096 - val_precision_6: 0.8544 - val_recall_6: 0.7802 - learning_rate: 5.0500e-04
# Epoch 17/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9495 - binary_accuracy: 0.8809 - loss: 0.2748 - precision_6: 0.8668 - recall_6: 0.8156 - val_auc_6: 0.9341 - val_binary_accuracy: 0.8645 - val_loss: 0.3188 - val_precision_6: 0.8300 - val_recall_6: 0.8089 - learning_rate: 4.0600e-04
# Epoch 18/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9544 - binary_accuracy: 0.8872 - loss: 0.2612 - precision_6: 0.8674 - recall_6: 0.8309 - val_auc_6: 0.9347 - val_binary_accuracy: 0.8662 - val_loss: 0.3125 - val_precision_6: 0.8462 - val_recall_6: 0.7916 - learning_rate: 3.0700e-04
# Epoch 19/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9566 - binary_accuracy: 0.8900 - loss: 0.2549 - precision_6: 0.8723 - recall_6: 0.8326 - val_auc_6: 0.9349 - val_binary_accuracy: 0.8668 - val_loss: 0.3196 - val_precision_6: 0.8379 - val_recall_6: 0.8050 - learning_rate: 2.0800e-04
# Epoch 20/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9590 - binary_accuracy: 0.8929 - loss: 0.2482 - precision_6: 0.8757 - recall_6: 0.8395 - val_auc_6: 0.9342 - val_binary_accuracy: 0.8665 - val_loss: 0.3219 - val_precision_6: 0.8519 - val_recall_6: 0.7852 - learning_rate: 1.0900e-04
# Epoch 21/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9617 - binary_accuracy: 0.8967 - loss: 0.2401 - precision_6: 0.8775 - recall_6: 0.8487 - val_auc_6: 0.9350 - val_binary_accuracy: 0.8671 - val_loss: 0.3198 - val_precision_6: 0.8478 - val_recall_6: 0.7923 - learning_rate: 1.0000e-05
# Epoch 22/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9604 - binary_accuracy: 0.8946 - loss: 0.2443 - precision_6: 0.8786 - recall_6: 0.8420 - val_auc_6: 0.9338 - val_binary_accuracy: 0.8656 - val_loss: 0.3230 - val_precision_6: 0.8374 - val_recall_6: 0.8018 - learning_rate: 1.0900e-04
# Epoch 23/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9597 - binary_accuracy: 0.8937 - loss: 0.2460 - precision_6: 0.8768 - recall_6: 0.8410 - val_auc_6: 0.9342 - val_binary_accuracy: 0.8657 - val_loss: 0.3205 - val_precision_6: 0.8400 - val_recall_6: 0.7984 - learning_rate: 2.0800e-04
# Epoch 24/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9604 - binary_accuracy: 0.8945 - loss: 0.2442 - precision_6: 0.8765 - recall_6: 0.8426 - val_auc_6: 0.9328 - val_binary_accuracy: 0.8655 - val_loss: 0.3283 - val_precision_6: 0.8556 - val_recall_6: 0.7772 - learning_rate: 3.0700e-04
# Epoch 25/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9601 - binary_accuracy: 0.8943 - loss: 0.2450 - precision_6: 0.8774 - recall_6: 0.8407 - val_auc_6: 0.9327 - val_binary_accuracy: 0.8617 - val_loss: 0.3257 - val_precision_6: 0.8145 - val_recall_6: 0.8233 - learning_rate: 4.0600e-04
# Epoch 26/40
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - auc_6: 0.9587 - binary_accuracy: 0.8928 - loss: 0.2491 - precision_6: 0.8757 - recall_6: 0.8391 - val_auc_6: 0.9317 - val_binary_accuracy: 0.8636 - val_loss: 0.3287 - val_precision_6: 0.8334 - val_recall_6: 0.8012 - learning_rate: 5.0500e-04

# %%
print(f"Forma de X_test: {X_test.shape}")
print(f"Forma de y_test_processed: {y_test_processed.shape}")
# Out:
# Forma de X_test: (798, 128, 128, 3)
# Forma de y_test_processed: (798, 128, 128, 1)

# %%
# Avaliando o modelo
y_test_processed = np.array([transform_red_to_white(mask) for mask in y_test])
y_test_processed = tf.expand_dims(y_test_processed, axis=-1)
result = unet_model.evaluate(X_test, y_test_processed)

# Verifique quantos valores foram retornados
print(result)

# Ajuste o número de variáveis de acordo com o retorno
(test_loss, test_accuracy, test_precision, test_recall, test_auc) = result

# Exibindo as métricas
print(f'Loss no conjunto de teste: {test_loss:.4f}')
print(f'Acurácia no conjunto de teste: {test_accuracy*100:.2f}%')
print(f'Recall no conjunto de teste: {test_recall*100:.2f}%')
print(f'Precisão no conjunto de teste: {test_precision*100:.2f}%')
print(f'AUC no conjunto de teste: {test_auc:.4f}')
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - auc_6: 0.9657 - binary_accuracy: 0.9041 - loss: 0.2329 - precision_6: 0.9130 - recall_6: 0.8285
# [0.23114825785160065, 0.9056485891342163, 0.9098430871963501, 0.8338398337364197, 0.9661136865615845]
# Loss no conjunto de teste: 0.2311
# Acurácia no conjunto de teste: 90.56%
# Recall no conjunto de teste: 83.38%
# Precisão no conjunto de teste: 90.98%
# AUC no conjunto de teste: 0.9661

# %%
import matplotlib.pyplot as plt

# Obter os valores de loss e val_loss do histórico de treinamento
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plotando o gráfico
epochs = range(1, len(train_loss) + 1)

plt.figure(figsize=(10, 6))

# Gráfico de loss de treinamento
plt.plot(epochs, train_loss, 'b-', label='Train Loss')

# Gráfico de loss de validação
plt.plot(epochs, val_loss, 'g-', label='Validation Loss')

# Plotar o loss de teste (como uma linha horizontal para comparação)
plt.axhline(y=test_loss, color='r', linestyle='--', label=f'Test Loss: {test_loss:.4f}')

# Configurações do gráfico
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Mostrar o gráfico
plt.show()

# %%
# Prevendo os valores do conjunto de teste
y_pred = unet_model.predict(X_test)

# Função para visualizar os resultados
def visualize_results(X, y_true, y_pred, num_samples=7):

    fig, axes = plt.subplots(num_samples, 4, figsize=(20, 5*num_samples))

    for i in range(num_samples):
        # Imagem Original
        axes[i, 0].imshow(np.squeeze(X[i]), cmap='viridis')
        axes[i, 0].set_title('Imagem Original')
        axes[i, 0].axis('off')

        # Máscara Verdadeira
        axes[i, 1].imshow(np.squeeze(y_true[i]), cmap='viridis')
        axes[i, 1].set_title('Máscara Verdadeira')
        axes[i, 1].axis('off')

        # Máscara Prevista
        axes[i, 2].imshow(np.squeeze(y_pred[i]), cmap='viridis')
        axes[i, 2].set_title('Máscara Prevista')
        axes[i, 2].axis('off')

        # Diferença entre a Máscara Verdadeira e Prevista
        diff = np.abs(np.squeeze(y_true[i]) - np.squeeze(y_pred[i]))
        axes[i, 3].imshow(diff, cmap='hot')
        axes[i, 3].set_title('Diferença')
        axes[i, 3].axis('off')

    plt.tight_layout()
    plt.show()

# Visualizando os resultados
visualize_results(X_test, y_test_processed, y_pred)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step

# %%
# Salvando o modelo treinado
unet_model.save('/content/drive/MyDrive/PROJETO/unet_vgg16_face_segmentation_10_09.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
